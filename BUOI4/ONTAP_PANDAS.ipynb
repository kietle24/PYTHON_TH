# %%
...
Trong **pandas**, đối tượng `DataFrame (df)` có rất nhiều hàm (method) hay dùng để thao tác, phân tích và xử lý dữ liệu. Dưới đây là danh sách **các hàm quan trọng và hay dùng nhất** kèm ví dụ ngắn:

---

### 1. Khám phá dữ liệu

* `df.head(n)` → Xem **n dòng đầu** (mặc định 5).
* `df.tail(n)` → Xem **n dòng cuối**.
* `df.shape` → Trả về `(số_dòng, số_cột)`.
* `df.info()` → Thông tin tổng quan: kiểu dữ liệu, số giá trị non-null.
* `df.describe()` → Thống kê mô tả.
* `df.columns` → Danh sách tên cột.
* `df.index` → Trả về chỉ số dòng.
* `df.dtypes` → Kiểu dữ liệu của từng cột.

---

### 2. Lọc, chọn dữ liệu

* `df['col']` → Lấy 1 cột.
* `df[['col1','col2']]` → Lấy nhiều cột.
* `df.iloc[0:5, 0:2]` → Lấy theo **chỉ số** (hàng, cột).
* `df.loc[0:5, ['col1','col2']]` → Lấy theo **tên nhãn**.
* `df[df['Age'] > 20]` → Lọc theo điều kiện.

---

### 3. Xử lý dữ liệu thiếu

* `df.isnull()` → Kiểm tra giá trị thiếu (NaN).
* `df.isnull().sum()` → Đếm số giá trị thiếu theo cột.
* `df.fillna(value)` → Điền giá trị thay thế.
* `df.dropna()` → Xóa hàng có giá trị thiếu.

---

### 4. Thống kê & toán học

* `df.mean()`, `df.median()`, `df.mode()` → Trung bình, trung vị, mode.
* `df.min()`, `df.max()` → Giá trị nhỏ nhất / lớn nhất.
* `df.sum()`, `df.cumsum()` → Tổng / tích lũy.
* `df.value_counts()` → Đếm tần suất xuất hiện (thường dùng cho 1 cột).

---

### 5. Biến đổi dữ liệu

* `df.rename(columns={'old':'new'})` → Đổi tên cột.
* `df.drop(columns=['col'])` → Xóa cột.
* `df.sort_values(by='col', ascending=True)` → Sắp xếp.
* `df.apply(func)` → Áp dụng hàm cho từng phần tử.
* `df['col'].map(func)` → Biến đổi từng giá trị trong 1 cột.

---

### 6. Gom nhóm & tổng hợp

* `df.groupby('col').mean()` → Nhóm theo cột rồi tính trung bình.
* `df.groupby('col').agg({'col2':'sum', 'col3':'mean'})` → Gom nhóm nhiều phép tính.
* `df.pivot_table(values='col1', index='col2', columns='col3', aggfunc='mean')` → Tạo pivot table.

---

### 7. Kết hợp dữ liệu

* `pd.concat([df1, df2])` → Nối theo hàng hoặc cột.
* `pd.merge(df1, df2, on='col')` → Join 2 bảng theo khóa.
* `df.join(df2)` → Join theo index.

---

### 8. Xuất / nhập dữ liệu

* `pd.read_csv('file.csv')` → Đọc file CSV.
* `df.to_csv('file.csv', index=False)` → Xuất ra CSV.
* `pd.read_excel('file.xlsx')`, `df.to_excel('file.xlsx')` → Excel.

---

Bạn có muốn tôi lập một **bảng tổng hợp ngắn gọn (hàm – chức năng – ví dụ)** để dễ tra cứu nhanh không?

...

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("chipolet.csv", sep= "\t")

# %%
df.head(5) #return 5 dong dau tien trong dataset
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#dataset over view: 4622 , 5 dong  
df.shape
# Out:
# (4622, 5)

# %%
df.info()  #thong tin ve dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
list(df.columns )#lay ten cot trong dataset
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %%
df.index #lay index cua dataset
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df.describe() #là một phương thức dùng để tóm tắt thống kê mô tả của data frame 
# o day thi cac cot da thong ke la kieu int no moi tinh duoc so lieu khong tra cac cot ma la kieu 
#khac int  
#
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
df.describe(include = "all") 
#thong ke tat cac ca string
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %% [markdown]
# ### loc vs iloc

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.tail
# Out:
# <bound method NDFrame.tail of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]>

# %%
df.dtypes #coi du lieu tung cot
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
df.head
# Out:
# <bound method NDFrame.head of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]>

# %%
df.loc[(df.quantity == 15) & (df.item_name == "Chips and Fresh Tomato Salsa"), ['order_id', 'quantity', 'item_name']]
# Out:
#       order_id  quantity                     item_name
# 1882       759         2  Chips and Fresh Tomato Salsa
# 2267       912         2  Chips and Fresh Tomato Salsa
# 2729      1083         2  Chips and Fresh Tomato Salsa

# %%
df.iloc[[11]]
# Out:
#     order_id  quantity             item_name  \
# 11         6         1  Chicken Crispy Tacos
#
#                                    choice_description item_price
# 11  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75

# %%
df.iloc[[10]]
# Out:
#     order_id  quantity            item_name choice_description item_price
# 10         5         1  Chips and Guacamole                NaN     $4.45

# %%
df.iloc[3:11,0:-1]
# Out:
#     order_id  quantity                              item_name  \
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
#
#                                    choice_description
# 3                                                 NaN
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 6                                                 NaN
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 8   [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...
# 9   [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...
# 10                                                NaN

# %%
df.iloc[3:11, :-1]
# Out:
#     order_id  quantity                              item_name  \
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
#
#                                    choice_description
# 3                                                 NaN
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 6                                                 NaN
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 8   [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...
# 9   [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...
# 10                                                NaN

# %%
x= df.iloc[3:11]
print(x)
# Out:
#     order_id  quantity                              item_name  \
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
#
#                                    choice_description item_price
# 3                                                 NaN     $2.39
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                 NaN     $1.69
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8   [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9   [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 10                                                NaN     $4.45

# %%
df.quantity.dtype
# Out:
# dtype('int64')

# %%
df.item_price.apply(lambda x:(x.replace('$', '')))
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: object

# %%
df["total_price"] = df["quantity"]*df["item_price"]
#tao mot hang moi la total_price "

# %%
#tinh doanh thu 
revenue = df["total_price"].sum()
print(revenue)
# Out:
# $2.39 $3.39 $3.39 $2.39 $16.98 $16.98 $10.98 $1.69 $11.75 $9.25 $9.25 $4.45 $8.75 $8.75 $11.25 $4.45 $2.39 $8.49 $8.49 $2.18 $2.18 $8.75 $4.45 $8.99 $3.39 $10.98 $3.39 $2.39 $8.49 $8.99 $1.09 $8.49 $2.39 $8.99 $1.69 $8.99 $1.09 $8.75 $8.75 $4.45 $2.95 $11.75 $2.15 $4.45 $11.25 $11.75 $8.75 $10.98 $8.99 $3.39 $8.99 $3.99 $8.99 $2.18 $2.18 $10.98 $1.09 $8.99 $2.39 $9.25 $11.25 $11.75 $2.15 $4.45 $9.25 $11.25 $8.75 $8.99 $8.99 $3.39 $8.99 $10.98 $8.99 $1.69 $8.99 $3.99 $8.75 $4.45 $8.75 $8.75 $2.15 $8.75 $11.25 $2.15 $9.25 $8.75 $8.75 $9.25 $8.49 $8.99 $1.09 $9.25 $2.95 $11.75 $11.75 $9.25 $11.75 $4.45 $9.25 $4.45 $11.75 $8.75 $8.75 $4.45 $8.99 $8.99 $3.99 $8.49 $3.39 $8.99 $1.09 $9.25 $4.45 $8.75 $2.95 $4.45 $2.39 $8.49 $8.99 $8.49 $1.09 $8.99 $3.99 $8.75 $9.25 $4.45 $11.25 $4.45 $8.99 $1.09 $9.25 $2.95 $4.45 $11.75 $4.45 $8.49 $2.39 $10.98 $22.50 $22.50 $11.75 $4.45 $11.25 $4.45 $11.25 $4.45 $11.25 $11.25 $11.75 $9.25 $4.45 $11.48 $17.98 $17.98 $1.69 $17.50 $17.50 $4.45 $8.49 $2.39 $17.50 $17.50 $4.45 $4.45 $11.25 $11.75 $10.98 $8.49 $10.98 $2.18 $2.18 $11.48 $8.49 $2.39 $4.45 $11.25 $11.75 $8.75 $8.49 $2.18 $2.18 $8.49 $3.39 $8.49 $8.99 $10.98 $11.48 $8.49 $1.09 $1.09 $9.25 $8.75 $2.95 $9.25 $4.45 $11.25 $11.48 $8.49 $8.49 $8.99 $2.39 $11.25 $8.75 $2.95 $1.09 $8.99 $8.49 $2.39 $10.98 $1.09 $3.99 $11.25 $8.75 $8.49 $3.39 $8.75 $9.25 $2.15 $11.25 $11.25 $11.25 $4.45 $22.50 $22.50 $4.45 $11.75 $8.75 $17.50 $17.50 $8.75 $9.25 $8.75 $2.15 $9.25 $4.30 $4.30 $8.75 $11.25 $2.15 $8.99 $1.09 $8.99 $3.99 $8.75 $2.95 $2.95 $11.75 $5.90 $5.90 $9.25 $9.25 $11.75 $9.25 $2.95 $17.50 $17.50 $8.75 $9.25 $10.98 $8.99 $1.09 $1.09 $1.09 $8.99 $10.98 $1.09 $8.75 $8.75 $9.25 $9.25 $8.75 $8.75 $8.99 $8.99 $8.99 $1.09 $11.75 $1.25 $8.99 $2.39 $9.25 $2.95 $8.99 $3.99 $8.49 $2.39 $8.49 $8.49 $8.49 $1.69 $8.49 $3.99 $8.99 $1.69 $1.09 $23.78 $23.78 $17.50 $17.50 $2.15 $8.75 $9.25 $9.25 $8.75 $4.45 $8.75 $11.25 $11.25 $1.25 $9.25 $4.45 $11.25 $11.75 $11.75 $6.49 $8.99 $2.39 $8.49 $2.39 $11.25 $8.75 $2.15 $8.99 $1.69 $8.75 $11.25 $2.15 $4.45 $8.75 $8.49 $8.99 $17.50 $17.50 $8.49 $1.09 $1.09 $8.75 $1.25 $2.15 $11.08 $8.49 $8.49 $8.99 $2.39 $8.75 $2.15 $1.50 $11.25 $2.15 $8.49 $8.49 $11.75 $9.25 $11.75 $1.25 $11.25 $8.75 $4.45 $6.49 $9.25 $2.95 $11.25 $4.45 $1.25 $1.25 $8.49 $2.39 $2.18 $2.18 $8.49 $2.18 $2.18 $22.16 $22.16 $17.50 $17.50 $8.75 $2.95 $6.49 $8.99 $3.39 $3.39 $8.99 $8.49 $11.25 $2.15 $11.25 $2.95 $11.25 $1.25 $8.99 $1.09 $8.75 $8.75 $9.25 $2.95 $11.75 $1.50 $8.99 $1.09 $11.25 $1.25 $1.25 $11.25 $11.75 $2.15 $8.99 $1.69 $11.75 $6.49 $8.75 $9.25 $11.25 $4.45 $1.25 $11.25 $4.45 $8.49 $8.99 $8.49 $8.99 $11.25 $1.25 $11.75 $1.25 $11.75 $9.25 $4.45 $11.25 $2.15 $32.94 $32.94 $32.94 $1.25 $11.25 $11.48 $1.69 $1.09 $17.50 $17.50 $4.45 $6.49 $9.25 $8.75 $9.25 $9.25 $8.75 $8.75 $2.15 $2.95 $17.50 $17.50 $10.98 $11.48 $11.48 $3.39 $8.99 $1.69 $8.99 $1.09 $10.98 $3.39 $8.99 $1.09 $9.25 $8.75 $11.25 $4.45 $2.95 $9.25 $22.20 $22.20 $22.20 $8.49 $8.99 $8.75 $8.75 $11.75 $8.75 $11.25 $9.25 $11.25 $11.25 $8.75 $11.25 $2.95 $1.25 $8.49 $1.69 $11.75 $11.25 $8.75 $8.75 $4.45 $8.49 $3.99 $8.49 $3.99 $11.48 $1.69 $1.09 $11.25 $1.50 $10.58 $1.69 $9.25 $11.25 $8.75 $9.25 $11.25 $11.25 $8.75 $11.75 $8.75 $8.75 $8.75 $2.15 $11.25 $11.75 $2.50 $2.50 $4.45 $9.25 $4.45 $11.25 $8.49 $3.99 $9.25 $9.25 $11.25 $9.25 $11.75 $11.25 $1.25 $23.50 $23.50 $1.25 $8.99 $8.49 $7.40 $7.40 $8.75 $1.25 $4.45 $8.75 $2.15 $8.75 $4.45 $7.40 $7.40 $7.40 $8.99 $3.99 $8.99 $1.69 $8.75 $8.75 $8.75 $8.75 $11.25 $11.25 $2.95 $8.75 $18.50 $18.50 $8.49 $3.99 $2.95 $9.25 $9.25 $3.00 $3.00 $1.25 $8.75 $9.25 $4.45 $8.75 $11.25 $4.45 $10.98 $22.16 $22.16 $4.45 $8.75 $9.25 $6.49 $9.25 $11.25 $8.75 $9.25 $2.15 $9.25 $4.45 $9.25 $2.95 $9.25 $8.75 $9.25 $1.25 $1.25 $8.75 $8.75 $9.25 $4.45 $11.75 $11.75 $11.75 $9.25 $9.25 $16.98 $16.98 $2.39 $3.39 $3.39 $9.25 $11.75 $11.25 $2.15 $8.75 $9.25 $4.45 $10.98 $11.25 $9.25 $22.50 $22.50 $9.25 $2.95 $1.50 $11.48 $8.49 $1.69 $8.49 $8.49 $8.49 $6.78 $6.78 $11.75 $4.45  ...

# %%
df.groupby("item_price").apply(print)
# Out:
#       order_id  quantity      item_name choice_description item_price  \
# 28          14         1    Canned Soda       [Dr. Pepper]     $1.09
# 34          17         1  Bottled Water                NaN     $1.09
# 53          24         1    Canned Soda           [Sprite]     $1.09
# 87          38         1  Bottled Water                NaN     $1.09
# 107         47         1    Canned Soda       [Dr. Pepper]     $1.09
# ...        ...       ...            ...                ...        ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]     $1.09
# 4001      1602         1  Bottled Water                NaN     $1.09
# 4008      1604         1    Canned Soda        [Diet Coke]     $1.09
# 4051      1621         1    Canned Soda           [Sprite]     $1.09
# 4069      1629         1  Bottled Water                NaN     $1.09
#
#      total price  total_price
# 28         $1.09       $1.09
# 34         $1.09       $1.09
# 53         $1.09       $1.09
# 87         $1.09       $1.09
# 107        $1.09       $1.09
# ...           ...         ...
# 3936       $1.09       $1.09
# 4001       $1.09       $1.09
# 4008       $1.09       $1.09
# 4051       $1.09       $1.09
# 4069       $1.09       $1.09
#
# [106 rows x 7 columns]
#       order_id  quantity          item_name choice_description item_price  \
# 263        114         1  Canned Soft Drink             [Coke]     $1.25
# 292        127         1  Canned Soft Drink           [Sprite]     $1.25
# 320        139         1  Canned Soft Drink             [Coke]     $1.25
# 337        147         1  Canned Soft Drink             [Coke]     $1.25
# 346        149         1  Canned Soft Drink         [Lemonade]     $1.25
# ...        ...       ...                ...                ...        ...
# 4585      1823         1  Canned Soft Drink        [Diet Coke]     $1.25
# 4597      1826         1  Canned Soft Drink           [Nestea]     $1.25
# 4601      1827         1  Canned Soft Drink        [Diet Coke]     $1.25
# 4606      1828         1  Canned Soft Drink             [Coke]     $1.25
# 4609      1829         1  Canned Soft Drink           [Sprite]     $1.25
#
#      total price  total_price
# 263        $1.25       $1.25
# 292        $1.25       $1.25
# 320        $1.25       $1.25
# 337        $1.25       $1.25
# 346        $1.25       $1.25
# ...           ...         ...
# 4585       $1.25       $1.25
# 4597       $1.25       $1.25
# 4601       $1.25       $1.25
# 4606       $1.25       $1.25
# 4609       $1.25       $1.25
#
# [264 rows x 7 columns]
#       order_id  quantity      item_name choice_description item_price  \
# 329        143         1  Bottled Water                NaN     $1.50
# 376        163         1  Bottled Water                NaN     $1.50
# 475        203         1  Bottled Water                NaN     $1.50
# 594        244         1  Bottled Water                NaN     $1.50
# 653        270         1  Bottled Water                NaN     $1.50
# ...        ...       ...            ...                ...        ...
# 4544      1806         1  Bottled Water                NaN     $1.50
# 4568      1817         1  Bottled Water                NaN     $1.50
# 4570      1817         1  Bottled Water                NaN     $1.50
# 4598      1826         1  Bottled Water                NaN     $1.50
# 4614      1831         1  Bottled Water                NaN     $1.50
#
#      total price  total_price
# 329        $1.50       $1.50
# 376        $1.50       $1.50
# 475        $1.50       $1.50
# 594        $1.50       $1.50
# 653        $1.50       $1.50
# ...           ...         ...
# 4544       $1.50       $1.50
# 4568       $1.50       $1.50
# 4570       $1.50       $1.50
# 4598       $1.50       $1.50
# 4614       $1.50       $1.50
#
# [117 rows x 7 columns]
#       order_id  quantity      item_name choice_description item_price  \
# 6            3         1  Side of Chips                NaN     $1.69
# 32          16         1  Side of Chips                NaN     $1.69
# 70          31         1  Side of Chips                NaN     $1.69
# 149         67         1  Side of Chips                NaN     $1.69
# 275        120         1  Side of Chips                NaN     $1.69
# ...        ...       ...            ...                ...        ...
# 3911      1569         1  Side of Chips                NaN     $1.69
# 3934      1578         1  Side of Chips                NaN     $1.69
# 4055      1623         1  Side of Chips                NaN     $1.69
# 4057      1624         1  Side of Chips                NaN     $1.69
# 4070      1629         1  Side of Chips                NaN     $1.69
#
#      total price  total_price
# 6          $1.69       $1.69
# 32         $1.69       $1.69
# 70         $1.69       $1.69
# 149        $1.69       $1.69
# 275        $1.69       $1.69
# ...           ...         ...
# 3911       $1.69       $1.69
# 3934       $1.69       $1.69
# 4055       $1.69       $1.69
# 4057       $1.69       $1.69
# 4070       $1.69       $1.69
#
# [99 rows x 7 columns]
#       order_id  quantity item_name choice_description item_price total price   \
# 4509      1793         1     Chips                NaN     $1.99        $1.99
#
#      total_price
# 4509      $1.99
#       order_id  quantity      item_name choice_description item_price  \
# 3599      1443         7  Bottled Water                NaN    $10.50
#
#                                            total price   \
# 3599  $10.50 $10.50 $10.50 $10.50 $10.50 $10.50 $10.50
#
#                                             total_price
# 3599  $10.50 $10.50 $10.50 $10.50 $10.50 $10.50 $10.50
#       order_id  quantity        item_name  \
# 476        204         1  Chicken Burrito
# 1099       453         1  Chicken Burrito
# 1160       479         1  Chicken Burrito
# 2919      1160         1     Chicken Bowl
# 3520      1415         1  Chicken Burrito
#
#                                      choice_description item_price  \
# 476   [Fresh Tomato (Mild), [Guacamole, Lettuce, Ric...    $10.58
# 1099  [Fresh Tomato (Mild), [Guacamole, Lettuce, Ric...    $10.58
# 1160  [Fresh Tomato (Mild), [Guacamole, Rice, Fajita...    $10.58
# 2919           [Fresh Tomato (Mild), [Guacamole, Rice]]    $10.58
# 3520  [Fresh Tomato (Mild), [Guacamole, Rice, Sour C...    $10.58
#
#      total price  total_price
# 476       $10.58      $10.58
# 1099      $10.58      $10.58
# 1160      $10.58      $10.58
# 2919      $10.58      $10.58
# 3520      $10.58      $10.58
#       order_id  quantity        item_name  \
# 5            3         1     Chicken Bowl
# 23          12         1  Chicken Burrito
# 45          21         1  Chicken Burrito
# 52          24         1  Chicken Burrito
# 68          30         1  Chicken Burrito
# ...        ...       ...              ...
# 3742      1496         1     Chicken Bowl
# 3794      1519         1  Chicken Burrito
# 3908      1567         1     Chicken Bowl
# 3967      1589         1  Chicken Burrito
# 4077      1632         1     Chicken Bowl
#
#                                      choice_description item_price  \
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...    $10.98
# 45    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $10.98
# 52    [Roasted Chili Corn Salsa (Medium), [Black Bea...    $10.98
# 68    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $10.98
# ...                                                 ...        ...
# 3742  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $10.98
# 3794  [Fresh Tomato Salsa (Mild), [Rice, Fajita Vegg...    $10.98
# 3908  [[Tomatillo-Green Chili Salsa (Medium), Roaste...    $10.98
# 3967  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $10.98
# 4077  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $10.98
#
#      total price  total_price
# 5         $10.98      $10.98
# 23        $10.98      $10.98
# 45        $10.98      $10.98
# 52        $10.98      $10.98
# 68        $10.98      $10.98
# ...           ...         ...
# 3742      $10.98      $10.98
# 3794      $10.98      $10.98
# 3908      $10.98      $10.98
# 3967      $10.98      $10.98
# 4077      $10.98      $10.98
#
# [99 rows x 7 columns]
#       order_id  quantity         item_name  \
# 322        140         1     Steak Burrito
# 822        339         1     Carnitas Bowl
# 825        341         1        Steak Bowl
# 1293       527         1        Steak Bowl
# 1294       527         1     Carnitas Bowl
# 1648       666         1  Barbacoa Burrito
# 1740       702         1     Carnitas Bowl
# 2884      1146         1  Carnitas Burrito
# 3140      1252         1     Steak Burrito
# 3251      1302         1     Steak Burrito
#
#                                      choice_description item_price  \
# 322   [Fresh Tomato (Mild), [Lettuce, Guacamole, Ric...    $11.08
# 822   [Fresh Tomato (Mild), [Guacamole, Sour Cream, ...    $11.08
# 825   [Fresh Tomato (Mild), [Guacamole, Lettuce, Pin...    $11.08
# 1293  [Fresh Tomato (Mild), [Guacamole, Lettuce, Pin...    $11.08
# 1294  [Fresh Tomato (Mild), [Guacamole, Lettuce, Ric...    $11.08
# 1648  [Fresh Tomato (Mild), [Guacamole, Rice, Black ...    $11.08
# 1740  [Fresh Tomato (Mild), [Guacamole, Sour Cream, ...    $11.08
# 2884  [Fresh Tomato (Mild), [Lettuce, Black Beans, G...    $11.08
# 3140  [Fresh Tomato (Mild), [Black Beans, Guacamole,...    $11.08
# 3251  [Fresh Tomato (Mild), [Lettuce, Guacamole, Pin...    $11.08
#
#      total price  total_price
# 322       $11.08      $11.08
# 822       $11.08      $11.08
# 825       $11.08      $11.08
# 1293      $11.08      $11.08
# 1294      $11.08      $11.08
# 1648      $11.08      $11.08
# 1740      $11.08      $11.08
# 2884      $11.08      $11.08
# 3140      $11.08      $11.08
# 3251      $11.08      $11.08
#       order_id  quantity           item_name  \
# 13           7         1        Chicken Bowl
# 42          20         1        Chicken Bowl
# 57          26         1      Veggie Burrito
# 62          28         1         Veggie Bowl
# 79          35         1  Chicken Soft Tacos
# ...        ...       ...                 ...
# 4589      1825         1        Chicken Bowl
# 4590      1825         1        Chicken Bowl
# 4608      1829         1      Veggie Burrito
# 4611      1830         1      Veggie Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
# 42    [Roasted Chili Corn Salsa, [Rice, Black Beans,...    $11.25
# 57    [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.25
# 62    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
# 79    [Roasted Chili Corn Salsa, [Rice, Cheese, Lett...    $11.25
# ...                                                 ...        ...
# 4589  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.25
# 4590  [Roasted Chili Corn Salsa, [Rice, Black Beans,...    $11.25
# 4608  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.25
# 4611  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...    $11.25
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
#
#      total price  total_price
# 13        $11.25      $11.25
# 42        $11.25      $11.25
# 57        $11.25      $11.25
# 62        $11.25      $11.25
# 79        $11.25      $11.25
# ...           ...         ...
# 4589      $11.25      $11.25
# 4590      $11.25      $11.25
# 4608      $11.25      $11.25
# 4611      $11.25      $11.25
# 4619      $11.25      $11.25
#
# [521 rows x 7 columns]
#       order_id  quantity              item_name  \
# 147         66         1          Steak Burrito
# 163         74         1          Carnitas Bowl
# 177         80         1          Steak Burrito
# 187         84         1             Steak Bowl
# 412        180         1             Steak Bowl
# 428        186         1             Steak Bowl
# 429        186         1  Barbacoa Crispy Tacos
# 471        202         1          Barbacoa Bowl
# 595        245         1             Steak Bowl
# 649        269         1          Steak Burrito
# 712        293         1          Steak Burrito
# 862        356         1          Steak Burrito
# 1042       429         1             Steak Bowl
# 1063       438         1       Carnitas Burrito
# 1072       442         1          Steak Burrito
# 1093       450         1          Steak Burrito
# 1144       472         1          Steak Burrito
# 1148       474         1             Steak Bowl
# 1174       483         1          Barbacoa Bowl
# 1175       483         1          Barbacoa Bowl
# 1235       504         1          Barbacoa Bowl
# 1236       504         1          Barbacoa Bowl
# 1275       519         1          Steak Burrito
# 1276       519         1          Steak Burrito
# 1321       539         1          Steak Burrito
# 1354       553         1             Steak Bowl
# 1383       562         1          Barbacoa Bowl
# 1384       562         1          Steak Burrito
# 1430       579         1          Carnitas Bowl
# 1461       593         1             Steak Bowl
# 1721       694         1       Steak Soft Tacos
# 2008       810         1          Steak Burrito
# 2009       810         1          Steak Burrito
# 2233       900         1          Carnitas Bowl
# 2236       901         1          Steak Burrito
# 2239       902         1       Carnitas Burrito
# 2488       988         1          Carnitas Bowl
# 2547      1010         1          Carnitas Bowl
# 2767      1098         1          Steak Burrito
# 3016      1199         1             Steak Bowl
# 3094      1233         1          Steak Burrito
# 3103      1238         1          Carnitas Bowl
# 3105      1239         1       Steak Soft Tacos
# 3184      1273         1    Barbacoa Soft Tacos
# 3204      1282         1          Steak Burrito
# 3273      1311         1          Steak Burrito
# 3276      1313         1       Barbacoa Burrito
# 3339      1339         1          Steak Burrito
# 3625      1451         1       Steak Soft Tacos
# 3792      1518         1          Carnitas Bowl
# 3865      1550         1             Steak Bowl
#
#                                      choice_description item_price  \
# 147   [Tomatillo-Green Chili Salsa (Medium), [Rice, ...    $11.48
# 163   [Roasted Chili Corn Salsa (Medium), [Pinto Bea...    $11.48
# 177   [Fresh Tomato Salsa (Mild), [Rice, Black Beans...    $11.48
# 187   [Fresh Tomato Salsa (Mild), [Rice, Fajita Vegg...    $11.48
# 412   [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...    $11.48
# 428   [[Roasted Chili Corn Salsa (Medium), Tomatillo...    $11.48
# 429   [[Roasted Chili Corn Salsa (Medium), Tomatillo...    $11.48
# 471   [[Tomatillo-Green Chili Salsa (Medium), Roaste...    $11.48
# 595   [[Roasted Chili Corn Salsa (Medium), Tomatillo...    $11.48
# 649   [Roasted Chili Corn Salsa (Medium), [Rice, Bla...    $11.48
# 712   [[Roasted Chili Corn Salsa (Medium), Fresh Tom...    $11.48
# 862   [Roasted Chili Corn Salsa (Medium), [Rice, Faj...    $11.48
# 1042  [Roasted Chili Corn Salsa (Medium), [Pinto Bea...    $11.48
# 1063  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $11.48
# 1072  [[Roasted Chili Corn Salsa (Medium), Tomatillo...    $11.48
# 1093  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...    $11.48
# 1144  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...    $11.48
# 1148  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...    $11.48
# 1174  [Tomatillo-Green Chili Salsa (Medium), [Black ...    $11.48
# 1175  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $11.48
# 1235  [Tomatillo-Green Chili Salsa (Medium), [Black ...    $11.48
# 1236  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $11.48
# 1275  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $11.48
# 1276  [Fresh Tomato Salsa (Mild), [Rice, Black Beans...    $11.48
# 1321  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...    $11.48
# 1354  [[Tomatillo-Green Chili Salsa (Medium), Roaste...    $11.48
# 1383  [[Tomatillo-Green Chili Salsa (Medium), Roaste...    $11.48
# 1384  [Fresh Tomato Salsa (Mild), [Cheese, Sour Crea...    $11.48
# 1430  [[Tomatillo-Red Chili Salsa (Hot), Fresh Tomat...    $11.48
# 1461  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...    $11.48
# 1721  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...    $11.48
# 2008  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...    $11.48
# 2009  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $11.48
# 2233  [Roasted Chili Corn Salsa (Medium), [Rice, Gua...    $11.48
# 2236  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...    $11.48
# 2239  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $11.48
# 2488  [[Tomatillo-Red Chili Salsa (Hot), Fresh Tomat...    $11.48
# 2547  [[Tomatillo-Red Chili Salsa (Hot), Fresh Tomat...    $11.48
# 2767  [Fresh Tomato Salsa (Mild), [Rice, Fajita Vegg...    $11.48
# 3016  [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...    $11.48
# 3094  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $11.48
# 3103  [Roasted Chili Corn Salsa (Medium), [Pinto Bea...    $11.48
# 3105  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $11.48
# 3184  [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...    $11.48
# 3204  [Fresh Tomato Salsa (Mild), [Rice, Fajita Vegg...    $11.48
# 3273  [Tomatillo-Red Chili Salsa (Hot), [Guacamole, ...    $11.48
# 3276  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $11.48
# 3339  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...    $11.48
# 3625  [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...    $11.48
# 3792  [Fresh Tomato Salsa (Mild), [Fajita Veggies, C...    $11.48
# 3865  [Roasted Chili Corn Salsa (Medium), [Rice, Faj...    $11.48
#
#      total price  total_price
# 147       $11.48      $11.48
# 163       $11.48      $11.48
# 177       $11.48      $11.48
# 187       $11.48      $11.48
# 412       $11.48      $11.48
# 428       $11.48      $11.48
# 429       $11.48      $11.48
# 471       $11.48      $11.48
# 595       $11.48      $11.48
# 649       $11.48      $11.48
# 712       $11.48      $11.48
# 862       $11.48      $11.48
# 1042      $11.48      $11.48
# 1063      $11.48      $11.48
# 1072      $11.48      $11.48
# 1093      $11.48      $11.48
# 1144      $11.48      $11.48
# 1148      $11.48      $11.48
# 1174      $11.48      $11.48
# 1175      $11.48      $11.48
# 1235      $11.48      $11.48
# 1236      $11.48      $11.48
# 1275      $11.48      $11.48
# 1276      $11.48      $11.48
# 1321      $11.48      $11.48
# 1354      $11.48      $11.48
# 1383      $11.48      $11.48
# 1384      $11.48      $11.48
# 1430      $11.48      $11.48
# 1461      $11.48      $11.48
# 1721      $11.48      $11.48
# 2008      $11.48      $11.48
# 2009      $11.48      $11.48
# 2233      $11.48      $11.48
# 2236      $11.48      $11.48
# 2239      $11.48      $11.48
# 2488      $11.48      $11.48
# 2547      $11.48      $11.48
# 2767      $11.48      $11.48
# 3016      $11.48      $11.48
# 3094      $11.48      $11.48
# 3103      $11.48      $11.48
# 3105      $11.48      $11.48
# 3184      $11.48      $11.48
# 3204      $11.48      $11.48
# 3273      $11.48      $11.48
# 3276      $11.48      $11.48
# 3339      $11.48      $11.48
# 3625      $11.48      $11.48
# 3792      $11.48      $11.48
# 3865      $11.48      $11.48
#       order_id  quantity      item_name choice_description item_price  \
# 4510      1793         1  Barbacoa Bowl        [Guacamole]    $11.49
#
#      total price  total_price
# 4510      $11.49      $11.49
#       order_id  quantity      item_name  \
# 7            4         1  Steak Burrito
# 39          19         1  Barbacoa Bowl
# 43          20         1  Steak Burrito
# 58          27         1  Barbacoa Bowl
# 90          40         1     Steak Bowl
# ...        ...       ...            ...
# 4594      1825         1  Barbacoa Bowl
# 4607      1829         1  Steak Burrito
# 4610      1830         1  Steak Burrito
# 4617      1833         1  Steak Burrito
# 4618      1833         1  Steak Burrito
#
#                                      choice_description item_price  \
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 39    [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $11.75
# 43    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...    $11.75
# 58    [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $11.75
# 90    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $11.75
# ...                                                 ...        ...
# 4594  [Roasted Chili Corn Salsa, [Pinto Beans, Sour ...    $11.75
# 4607  [Tomatillo Green Chili Salsa, [Rice, Cheese, S...    $11.75
# 4610  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
#
#      total price  total_price
# 7         $11.75      $11.75
# 39        $11.75      $11.75
# 43        $11.75      $11.75
# 58        $11.75      $11.75
# 90        $11.75      $11.75
# ...           ...         ...
# 4594      $11.75      $11.75
# 4607      $11.75      $11.75
# 4610      $11.75      $11.75
# 4617      $11.75      $11.75
# 4618      $11.75      $11.75
#
# [284 rows x 7 columns]
#       order_id  quantity                     item_name choice_description  \
# 1257       511         4  Chips and Fresh Tomato Salsa                NaN
#
#      item_price                  total price                    total_price
# 1257    $11.80   $11.80 $11.80 $11.80 $11.80   $11.80 $11.80 $11.80 $11.80
#       order_id  quantity            item_name  \
# 606        250         1     Steak Salad Bowl
# 749        309         1     Steak Salad Bowl
# 1132       468         1  Carnitas Salad Bowl
# 1159       478         1     Steak Salad Bowl
# 1229       501         1  Barbacoa Salad Bowl
# 1311       534         1     Steak Salad Bowl
# 1326       541         1  Barbacoa Salad Bowl
# 1505       612         1     Steak Salad Bowl
# 1571       637         1     Steak Salad Bowl
# 1590       644         1     Steak Salad Bowl
# 1816       734         1     Steak Salad Bowl
# 2401       953         1     Steak Salad Bowl
# 2439       969         1     Steak Salad Bowl
# 2442       970         1  Barbacoa Salad Bowl
# 2610      1035         1  Carnitas Salad Bowl
# 2740      1088         1     Steak Salad Bowl
# 2804      1114         1     Steak Salad Bowl
# 2957      1176         1     Steak Salad Bowl
# 3120      1244         1     Steak Salad Bowl
# 3208      1283         1  Barbacoa Salad Bowl
# 3350      1343         1     Steak Salad Bowl
# 3493      1403         1     Steak Salad Bowl
# 3546      1426         1  Barbacoa Salad Bowl
# 3749      1499         1  Carnitas Salad Bowl
# 4239      1692         1  Carnitas Salad Bowl
# 4313      1720         1     Steak Salad Bowl
#
#                                      choice_description item_price  \
# 606   [Fresh Tomato Salsa, [Pinto Beans, Cheese, Gua...    $11.89
# 749   [Roasted Chili Corn Salsa, [Rice, Cheese, Lett...    $11.89
# 1132  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $11.89
# 1159  [Fresh Tomato Salsa, [Rice, Fajita Vegetables,...    $11.89
# 1229  [Fresh Tomato Salsa, [Rice, Fajita Vegetables,...    $11.89
# 1311  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $11.89
# 1326  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.89
# 1505  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...    $11.89
# 1571  [Fresh Tomato Salsa, [Fajita Vegetables, Sour ...    $11.89
# 1590  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.89
# 1816  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $11.89
# 2401  [Fresh Tomato Salsa, [Fajita Vegetables, Guaca...    $11.89
# 2439  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.89
# 2442  [Tomatillo Green Chili Salsa, [Rice, Fajita Ve...    $11.89
# 2610  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $11.89
# 2740  [Fresh Tomato Salsa, [Fajita Vegetables, Black...    $11.89
# 2804  [Tomatillo Red Chili Salsa, [Rice, Black Beans...    $11.89
# 2957  [Fresh Tomato Salsa, [Black Beans, Cheese, Gua...    $11.89
# 3120  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $11.89
# 3208  [Tomatillo Red Chili Salsa, [Black Beans, Chee...    $11.89
# 3350  [Fresh Tomato Salsa, [Cheese, Guacamole, Lettu...    $11.89
# 3493  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $11.89
# 3546                    [Fresh Tomato Salsa, Guacamole]    $11.89
# 3749  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $11.89
# 4239  [Tomatillo Green Chili Salsa, [Black Beans, Ch...    $11.89
# 4313  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    $11.89
#
#      total price  total_price
# 606       $11.89      $11.89
# 749       $11.89      $11.89
# 1132      $11.89      $11.89
# 1159      $11.89      $11.89
# 1229      $11.89      $11.89
# 1311      $11.89      $11.89
# 1326      $11.89      $11.89
# 1505      $11.89      $11.89
# 1571      $11.89      $11.89
# 1590      $11.89      $11.89
# 1816      $11.89      $11.89
# 2401      $11.89      $11.89
# 2439      $11.89      $11.89
# 2442      $11.89      $11.89
# 2610      $11.89      $11.89
# 2740      $11.89      $11.89
# 2804      $11.89      $11.89
# 2957      $11.89      $11.89
# 3120      $11.89      $11.89
# 3208      $11.89      $11.89
# 3350      $11.89      $11.89
# 3493      $11.89      $11.89
# 3546      $11.89      $11.89
# 3749      $11.89      $11.89
# 4239      $11.89      $11.89
# 4313      $11.89      $11.89
#       order_id  quantity          item_name choice_description item_price  \
# 3389      1360         2  6 Pack Soft Drink        [Diet Coke]    $12.98
#
#         total price      total_price
# 3389  $12.98 $12.98   $12.98 $12.98
#       order_id  quantity            item_name choice_description item_price  \
# 2645      1051         3  Chips and Guacamole                NaN    $13.35
#
#                total price             total_price
# 2645  $13.35 $13.35 $13.35   $13.35 $13.35 $13.35
#       order_id  quantity      item_name choice_description item_price  \
# 3887      1559         8  Side of Chips                NaN    $13.52
#
#                                            total price   \
# 3887  $13.52 $13.52 $13.52 $13.52 $13.52 $13.52 $13....
#
#                                             total_price
# 3887  $13.52 $13.52 $13.52 $13.52 $13.52 $13.52 $13....
#       order_id  quantity      item_name choice_description item_price  \
# 4152      1660        10  Bottled Water                NaN    $15.00
#
#                                            total price   \
# 4152  $15.00 $15.00 $15.00 $15.00 $15.00 $15.00 $15....
#
#                                             total_price
# 4152  $15.00 $15.00 $15.00 $15.00 $15.00 $15.00 $15....
#       order_id  quantity        item_name choice_description item_price  \
# 3823      1533         2  Chicken Burrito  [[Lettuce, Rice]]    $16.38
#
#         total price      total_price
# 3823  $16.38 $16.38   $16.38 $16.38
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 577        237         2    Chicken Soft Tacos
# 846        348         2           Veggie Bowl
# 2339       932         2          Chicken Bowl
# 2580      1023         2          Chicken Bowl
# 2771      1100         2          Chicken Bowl
# 3080      1227         2          Chicken Bowl
# 3133      1249         2          Chicken Bowl
# 3375      1355         2       Chicken Burrito
# 3612      1447         2          Chicken Bowl
# 3615      1449         2       Chicken Burrito
# 3617      1449         2           Veggie Bowl
# 3618      1449         2          Chicken Bowl
# 3663      1465         2          Chicken Bowl
# 3689      1478         2       Chicken Burrito
# 3888      1559         2    Chicken Soft Tacos
# 3889      1559         2     Veggie Soft Tacos
# 3891      1559         2  Chicken Crispy Tacos
# 3976      1593         2          Chicken Bowl
#
#                                      choice_description item_price  \
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 577   [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...    $16.98
# 846   [Fresh Tomato Salsa (Mild), [Rice, Sour Cream,...    $16.98
# 2339  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...    $16.98
# 2580  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...    $16.98
# 2771  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...    $16.98
# 3080  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...    $16.98
# 3133  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...    $16.98
# 3375  [Roasted Chili Corn Salsa (Medium), [Black Bea...    $16.98
# 3612  [Tomatillo-Red Chili Salsa (Hot), [Cheese, Sou...    $16.98
# 3615  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $16.98
# 3617  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $16.98
# 3618  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $16.98
# 3663  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...    $16.98
# 3689  [Roasted Chili Corn Salsa (Medium), [Sour Crea...    $16.98
# 3888  [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice...    $16.98
# 3889  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $16.98
# 3891  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $16.98
# 3976  [[Roasted Chili Corn Salsa (Medium), Fresh Tom...    $16.98
#
#         total price      total_price
# 4     $16.98 $16.98   $16.98 $16.98
# 577   $16.98 $16.98   $16.98 $16.98
# 846   $16.98 $16.98   $16.98 $16.98
# 2339  $16.98 $16.98   $16.98 $16.98
# 2580  $16.98 $16.98   $16.98 $16.98
# 2771  $16.98 $16.98   $16.98 $16.98
# 3080  $16.98 $16.98   $16.98 $16.98
# 3133  $16.98 $16.98   $16.98 $16.98
# 3375  $16.98 $16.98   $16.98 $16.98
# 3612  $16.98 $16.98   $16.98 $16.98
# 3615  $16.98 $16.98   $16.98 $16.98
# 3617  $16.98 $16.98   $16.98 $16.98
# 3618  $16.98 $16.98   $16.98 $16.98
# 3663  $16.98 $16.98   $16.98 $16.98
# 3689  $16.98 $16.98   $16.98 $16.98
# 3888  $16.98 $16.98   $16.98 $16.98
# 3889  $16.98 $16.98   $16.98 $16.98
# 3891  $16.98 $16.98   $16.98 $16.98
# 3976  $16.98 $16.98   $16.98 $16.98
#       order_id  quantity             item_name  \
# 150         68         2       Chicken Burrito
# 154         70         2          Chicken Bowl
# 217         96         2  Chicken Crispy Tacos
# 241        105         2       Chicken Burrito
# 282        124         2          Chicken Bowl
# 315        137         2    Chicken Salad Bowl
# 354        153         2    Chicken Soft Tacos
# 415        181         2          Chicken Bowl
# 426        185         2    Chicken Soft Tacos
# 654        271         2          Chicken Bowl
# 885        366         2  Chicken Crispy Tacos
# 976        401         2          Chicken Bowl
# 1017       418         2          Chicken Bowl
# 1106       457         2          Chicken Bowl
# 1166       481         2       Chicken Burrito
# 1219       497         2       Chicken Burrito
# 1434       581         2       Chicken Burrito
# 1588       643         2          Chicken Bowl
# 1656       670         2       Chicken Burrito
# 1845       747         2       Chicken Burrito
# 1981       800         2       Chicken Burrito
# 2045       823         2       Chicken Burrito
# 2051       826         2       Chicken Burrito
# 2061       831         2       Chicken Burrito
# 2106       848         2          Chicken Bowl
# 2589      1027         2       Chicken Burrito
# 2598      1031         2       Chicken Burrito
# 2637      1048         2       Chicken Burrito
# 2953      1174         2       Chicken Burrito
# 2975      1183         2       Chicken Burrito
# 3167      1265         2    Chicken Salad Bowl
# 3236      1295         2       Chicken Burrito
# 3423      1374         2          Chicken Bowl
# 3674      1471         2       Chicken Burrito
# 3767      1509         2       Chicken Burrito
# 3918      1572         2       Chicken Burrito
# 4093      1640         2       Chicken Burrito
# 4148      1660         2       Chicken Burrito
# 4435      1767         2          Chicken Bowl
# 4561      1813         2    Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 150   [Tomatillo Red Chili Salsa, [Rice, Black Beans...    $17.50
# 154   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $17.50
# 217   [Tomatillo Red Chili Salsa, [Cheese, Sour Crea...    $17.50
# 241   [Tomatillo Red Chili Salsa, [Rice, Black Beans...    $17.50
# 282   [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $17.50
# 315             [Fresh Tomato Salsa, Fajita Vegetables]    $17.50
# 354                    [Fresh Tomato Salsa, Sour Cream]    $17.50
# 415                         [Tomatillo Red Chili Salsa]    $17.50
# 426         [Fresh Tomato Salsa, [Sour Cream, Lettuce]]    $17.50
# 654   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $17.50
# 885                         [Tomatillo Red Chili Salsa]    $17.50
# 976   [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $17.50
# 1017  [Fresh Tomato Salsa, [Rice, Cheese, Black Beans]]    $17.50
# 1106  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $17.50
# 1166                         [Fresh Tomato Salsa, Rice]    $17.50
# 1219  [Tomatillo Red Chili Salsa, [Cheese, Rice, Bla...    $17.50
# 1434                         [Fresh Tomato Salsa, Rice]    $17.50
# 1588  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $17.50
# 1656                  [Tomatillo Red Chili Salsa, Rice]    $17.50
# 1845  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $17.50
# 1981  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $17.50
# 2045                         [Fresh Tomato Salsa, Rice]    $17.50
# 2051  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $17.50
# 2061  [Fresh Tomato Salsa, [Lettuce, Rice, Black Bea...    $17.50
# 2106  [Fresh Tomato Salsa, [Black Beans, Cheese, Sou...    $17.50
# 2589  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $17.50
# 2598  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $17.50
# 2637  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $17.50
# 2953  [Fresh Tomato Salsa, [Cheese, Rice, Black Bean...    $17.50
# 2975  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $17.50
# 3167  [Fresh Tomato Salsa, [Pinto Beans, Cheese, Let...    $17.50
# 3236  [Fresh Tomato Salsa, [Sour Cream, Cheese, Pint...    $17.50
# 3423  [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream...    $17.50
# 3674  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $17.50
# 3767  [Tomatillo Red Chili Salsa, [Rice, Black Beans...    $17.50
# 3918  [Tomatillo Red Chili Salsa, [Cheese, Black Bea...    $17.50
# 4093  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $17.50
# 4148                         [Fresh Tomato Salsa, Rice]    $17.50
# 4435  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...    $17.50
# 4561  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $17.50
#
#         total price      total_price
# 150   $17.50 $17.50   $17.50 $17.50
# 154   $17.50 $17.50   $17.50 $17.50
# 217   $17.50 $17.50   $17.50 $17.50
# 241   $17.50 $17.50   $17.50 $17.50
# 282   $17.50 $17.50   $17.50 $17.50
# 315   $17.50 $17.50   $17.50 $17.50
# 354   $17.50 $17.50   $17.50 $17.50
# 415   $17.50 $17.50   $17.50 $17.50
# 426   $17.50 $17.50   $17.50 $17.50
# 654   $17.50 $17.50   $17.50 $17.50
# 885   $17.50 $17.50   $17.50 $17.50
# 976   $17.50 $17.50   $17.50 $17.50
# 1017  $17.50 $17.50   $17.50 $17.50
# 1106  $17.50 $17.50   $17.50 $17.50
# 1166  $17.50 $17.50   $17.50 $17.50
# 1219  $17.50 $17.50   $17.50 $17.50
# 1434  $17.50 $17.50   $17.50 $17.50
# 1588  $17.50 $17.50   $17.50 $17.50
# 1656  $17.50 $17.50   $17.50 $17.50
# 1845  $17.50 $17.50   $17.50 $17.50
# 1981  $17.50 $17.50   $17.50 $17.50
# 2045  $17.50 $17.50   $17.50 $17.50
# 2051  $17.50 $17.50   $17.50 $17.50
# 2061  $17.50 $17.50   $17.50 $17.50
# 2106  $17.50 $17.50   $17.50 $17.50
# 2589  $17.50 $17.50   $17.50 $17.50
# 2598  $17.50 $17.50   $17.50 $17.50
# 2637  $17.50 $17.50   $17.50 $17.50
# 2953  $17.50 $17.50   $17.50 $17.50
# 2975  $17.50 $17.50   $17.50 $17.50
# 3167  $17.50 $17.50   $17.50 $17.50
# 3236  $17.50 $17.50   $17.50 $17.50
# 3423  $17.50 $17.50   $17.50 $17.50
# 3674  $17.50 $17.50   $17.50 $17.50
# 3767  $17.50 $17.50   $17.50 $17.50
# 3918  $17.50 $17.50   $17.50 $17.50
# 4093  $17.50 $17.50   $17.50 $17.50
# 4148  $17.50 $17.50   $17.50 $17.50
# 4435  $17.50 $17.50   $17.50 $17.50
# 4561  $17.50 $17.50   $17.50 $17.50
#       order_id  quantity            item_name choice_description item_price  \
# 4489      1786         4  Chips and Guacamole                NaN    $17.80
#
#                       total price                    total_price
# 4489  $17.80 $17.80 $17.80 $17.80   $17.80 $17.80 $17.80 $17.80
#       order_id  quantity              item_name  \
# 148         67         2          Steak Burrito
# 910        377         2             Steak Bowl
# 1262       513         2          Steak Burrito
# 2380       947         2          Steak Burrito
# 2874      1142         2     Steak Crispy Tacos
# 3616      1449         2          Steak Burrito
# 3890      1559         2  Carnitas Crispy Tacos
#
#                                      choice_description item_price  \
# 148   [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...    $17.98
# 910   [Roasted Chili Corn Salsa (Medium), [Black Bea...    $17.98
# 1262  [[Tomatillo-Green Chili Salsa (Medium), Tomati...    $17.98
# 2380  [Fresh Tomato Salsa (Mild), [Pinto Beans, Chee...    $17.98
# 2874  [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...    $17.98
# 3616  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...    $17.98
# 3890     [Fresh Tomato Salsa (Mild), [Cheese, Lettuce]]    $17.98
#
#         total price      total_price
# 148   $17.98 $17.98   $17.98 $17.98
# 910   $17.98 $17.98   $17.98 $17.98
# 1262  $17.98 $17.98   $17.98 $17.98
# 2380  $17.98 $17.98   $17.98 $17.98
# 2874  $17.98 $17.98   $17.98 $17.98
# 3616  $17.98 $17.98   $17.98 $17.98
# 3890  $17.98 $17.98   $17.98 $17.98
#       order_id  quantity              item_name  \
# 534        223         2          Steak Burrito
# 638        264         2          Steak Burrito
# 1903       768         2  Barbacoa Crispy Tacos
# 2581      1024         2       Carnitas Burrito
# 3134      1250         2          Steak Burrito
# 3354      1345         2             Steak Bowl
# 3861      1548         2          Steak Burrito
# 3970      1591         2          Steak Burrito
# 4082      1634         2             Steak Bowl
# 4232      1690         2             Steak Bowl
# 4310      1719         2          Steak Burrito
# 4354      1738         2       Steak Soft Tacos
#
#                                      choice_description item_price  \
# 534   [Fresh Tomato Salsa, [Sour Cream, Lettuce, Che...    $18.50
# 638    [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]    $18.50
# 1903   [Fresh Tomato Salsa, [Sour Cream, Cheese, Rice]]    $18.50
# 2581  [Tomatillo Red Chili Salsa, [Rice, Pinto Beans...    $18.50
# 3134  [Tomatillo Red Chili Salsa, [Cheese, Black Bea...    $18.50
# 3354  [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]    $18.50
# 3861  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $18.50
# 3970  [Fresh Tomato Salsa, [Lettuce, Sour Cream, Che...    $18.50
# 4082  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...    $18.50
# 4232  [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]    $18.50
# 4310  [Tomatillo Red Chili Salsa, [Rice, Black Beans...    $18.50
# 4354            [Fresh Tomato Salsa, [Cheese, Lettuce]]    $18.50
#
#         total price      total_price
# 534   $18.50 $18.50   $18.50 $18.50
# 638   $18.50 $18.50   $18.50 $18.50
# 1903  $18.50 $18.50   $18.50 $18.50
# 2581  $18.50 $18.50   $18.50 $18.50
# 3134  $18.50 $18.50   $18.50 $18.50
# 3354  $18.50 $18.50   $18.50 $18.50
# 3861  $18.50 $18.50   $18.50 $18.50
# 3970  $18.50 $18.50   $18.50 $18.50
# 4082  $18.50 $18.50   $18.50 $18.50
# 4232  $18.50 $18.50   $18.50 $18.50
# 4310  $18.50 $18.50   $18.50 $18.50
# 4354  $18.50 $18.50   $18.50 $18.50
#       order_id  quantity item_name choice_description item_price total price   \
# 40          19         1     Chips                NaN     $2.15        $2.15
# 59          27         1     Chips                NaN     $2.15        $2.15
# 77          34         1     Chips                NaN     $2.15        $2.15
# 80          35         1     Chips                NaN     $2.15        $2.15
# 208         92         1     Chips                NaN     $2.15        $2.15
# ...        ...       ...       ...                ...        ...          ...
# 4497      1788         1     Chips                NaN     $2.15        $2.15
# 4505      1791         1     Chips                NaN     $2.15        $2.15
# 4525      1799         1     Chips                NaN     $2.15        $2.15
# 4584      1823         1     Chips                NaN     $2.15        $2.15
# 4613      1831         1     Chips                NaN     $2.15        $2.15
#
#      total_price
# 40        $2.15
# 59        $2.15
# 77        $2.15
# 80        $2.15
# 208       $2.15
# ...          ...
# 4497      $2.15
# 4505      $2.15
# 4525      $2.15
# 4584      $2.15
# 4613      $2.15
#
# [192 rows x 7 columns]
#       order_id  quantity      item_name choice_description item_price  \
# 18           9         2    Canned Soda           [Sprite]     $2.18
# 51          23         2    Canned Soda     [Mountain Dew]     $2.18
# 162         73         2    Canned Soda        [Diet Coke]     $2.18
# 171         76         2    Canned Soda  [Diet Dr. Pepper]     $2.18
# 350        150         2    Canned Soda        [Diet Coke]     $2.18
# 352        151         2    Canned Soda        [Coca Cola]     $2.18
# 698        287         2    Canned Soda        [Coca Cola]     $2.18
# 700        288         2    Canned Soda        [Coca Cola]     $2.18
# 909        376         2    Canned Soda     [Mountain Dew]     $2.18
# 1091       450         2    Canned Soda       [Dr. Pepper]     $2.18
# 1092       450         2    Canned Soda        [Coca Cola]     $2.18
# 1177       484         2  Bottled Water                NaN     $2.18
# 1182       485         2  Bottled Water                NaN     $2.18
# 1944       787         2    Canned Soda       [Dr. Pepper]     $2.18
# 2135       859         2    Canned Soda        [Diet Coke]     $2.18
# 2905      1156         2    Canned Soda        [Coca Cola]     $2.18
# 2906      1156         2    Canned Soda           [Sprite]     $2.18
# 2998      1192         2  Bottled Water                NaN     $2.18
# 3152      1258         2    Canned Soda       [Dr. Pepper]     $2.18
# 3364      1349         2    Canned Soda        [Coca Cola]     $2.18
# 3592      1440         2    Canned Soda        [Diet Coke]     $2.18
# 3866      1550         2    Canned Soda     [Mountain Dew]     $2.18
#
#       total price    total_price
# 18    $2.18 $2.18   $2.18 $2.18
# 51    $2.18 $2.18   $2.18 $2.18
# 162   $2.18 $2.18   $2.18 $2.18
# 171   $2.18 $2.18   $2.18 $2.18
# 350   $2.18 $2.18   $2.18 $2.18
# 352   $2.18 $2.18   $2.18 $2.18
# 698   $2.18 $2.18   $2.18 $2.18
# 700   $2.18 $2.18   $2.18 $2.18
# 909   $2.18 $2.18   $2.18 $2.18
# 1091  $2.18 $2.18   $2.18 $2.18
# 1092  $2.18 $2.18   $2.18 $2.18
# 1177  $2.18 $2.18   $2.18 $2.18
# 1182  $2.18 $2.18   $2.18 $2.18
# 1944  $2.18 $2.18   $2.18 $2.18
# 2135  $2.18 $2.18   $2.18 $2.18
# 2905  $2.18 $2.18   $2.18 $2.18
# 2906  $2.18 $2.18   $2.18 $2.18
# 2998  $2.18 $2.18   $2.18 $2.18
# 3152  $2.18 $2.18   $2.18 $2.18
# 3364  $2.18 $2.18   $2.18 $2.18
# 3592  $2.18 $2.18   $2.18 $2.18
# 3866  $2.18 $2.18   $2.18 $2.18
#       order_id  quantity                     item_name choice_description  \
# 730        301         1  Chips and Fresh Tomato Salsa                NaN
# 3102      1237         1  Chips and Fresh Tomato Salsa                NaN
# 3826      1533         1  Chips and Fresh Tomato Salsa                NaN
#
#      item_price total price  total_price
# 730      $2.29        $2.29       $2.29
# 3102     $2.29        $2.29       $2.29
# 3826     $2.29        $2.29       $2.29
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 15           8         1  Chips and Tomatillo-Green Chili Salsa
# 25          13         1           Chips and Fresh Tomato Salsa
# 30          15         1  Chips and Tomatillo-Green Chili Salsa
# ...        ...       ...                                    ...
# 3907      1566         1           Chips and Fresh Tomato Salsa
# 3983      1596         1           Chips and Fresh Tomato Salsa
# 4007      1604         1  Chips and Tomatillo-Green Chili Salsa
# 4088      1637         1    Chips and Tomatillo-Red Chili Salsa
# 4090      1638         1           Chips and Fresh Tomato Salsa
#
#      choice_description item_price total price  total_price
# 0                   NaN     $2.39        $2.39       $2.39
# 3                   NaN     $2.39        $2.39       $2.39
# 15                  NaN     $2.39        $2.39       $2.39
# 25                  NaN     $2.39        $2.39       $2.39
# 30                  NaN     $2.39        $2.39       $2.39
# ...                 ...        ...          ...         ...
# 3907                NaN     $2.39        $2.39       $2.39
# 3983                NaN     $2.39        $2.39       $2.39
# 4007                NaN     $2.39        $2.39       $2.39
# 4088                NaN     $2.39        $2.39       $2.39
# 4090                NaN     $2.39        $2.39       $2.39
#
# [100 rows x 7 columns]
#       order_id  quantity          item_name choice_description item_price  \
# 492        206         2  Canned Soft Drink        [Diet Coke]     $2.50
# 651        270         2  Canned Soft Drink             [Coke]     $2.50
# 791        325         2  Canned Soft Drink             [Coke]     $2.50
# 1338       546         2  Canned Soft Drink             [Coke]     $2.50
# 1373       560         2  Canned Soft Drink             [Coke]     $2.50
# 1377       561         2  Canned Soft Drink         [Lemonade]     $2.50
# 1412       574         2  Canned Soft Drink        [Diet Coke]     $2.50
# 1760       710         2  Canned Soft Drink        [Diet Coke]     $2.50
# 1878       759         2  Canned Soft Drink             [Coke]     $2.50
# 1879       759         2  Canned Soft Drink        [Diet Coke]     $2.50
# 2274       915         2  Canned Soft Drink             [Coke]     $2.50
# 2513       999         2  Canned Soft Drink           [Sprite]     $2.50
# 2766      1097         2  Canned Soft Drink        [Diet Coke]     $2.50
# 2995      1191         2  Canned Soft Drink           [Sprite]     $2.50
# ...
# 4075      1631         1     Chicken Bowl
# 4083      1635         1   Veggie Burrito
# 4084      1635         1     Veggie Salad
# 4087      1637         1     Chicken Bowl
#
#                                      choice_description item_price  \
# 16    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...     $8.49
# 17    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...     $8.49
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...     $8.49
# 29    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...     $8.49
# 85    [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...     $8.49
# ...                                                 ...        ...
# 4071  [Fresh Tomato Salsa (Mild), [Black Beans, Rice...     $8.49
# 4075  [Roasted Chili Corn Salsa (Medium), [Black Bea...     $8.49
# 4083  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...     $8.49
# 4084  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...     $8.49
# 4087  [[Fresh Tomato Salsa (Mild), Roasted Chili Cor...     $8.49
#
#      total price  total_price
# 16         $8.49       $8.49
# 17         $8.49       $8.49
# 26         $8.49       $8.49
# 29         $8.49       $8.49
# 85         $8.49       $8.49
# ...           ...         ...
# 4071       $8.49       $8.49
# 4075       $8.49       $8.49
# 4083       $8.49       $8.49
# 4084       $8.49       $8.49
# 4087       $8.49       $8.49
#
# [311 rows x 7 columns]
#       order_id  quantity            item_name choice_description item_price  \
# 4235      1691         1         Chicken Bowl       [White Rice]     $8.50
# 4236      1691         1         Chicken Bowl       [White Rice]     $8.50
# 4237      1691         2  Chips and Guacamole                NaN     $8.50
#
#       total price    total_price
# 4235        $8.50         $8.50
# 4236        $8.50         $8.50
# 4237  $8.50 $8.50   $8.50 $8.50
#       order_id  quantity           item_name  \
# 728        301         1       Steak Burrito
# 729        301         1  Steak Crispy Tacos
# 926        382         1          Steak Bowl
# 1272       517         1       Steak Burrito
# 3156      1260         1    Barbacoa Burrito
# 3195      1278         1       Barbacoa Bowl
# 3196      1278         1          Steak Bowl
# 3252      1302         1    Carnitas Burrito
# 3501      1406         1       Steak Burrito
# 3502      1406         1         Steak Salad
# 3529      1419         1    Carnitas Burrito
# 3530      1419         1       Steak Burrito
# 3532      1420         1       Steak Burrito
# 3540      1423         1       Steak Burrito
# 3822      1533         1       Barbacoa Bowl
# 3902      1564         1    Barbacoa Burrito
# 3988      1598         1       Steak Burrito
# 4056      1624         1       Barbacoa Bowl
# 4068      1628         1       Steak Burrito
#
#                                      choice_description item_price  \
# 728   [Roasted Chili Corn (Medium), [Sour Cream, Che...     $8.69
# 729            [Fresh Tomato (Mild), [Lettuce, Cheese]]     $8.69
# 926   [Fresh Tomato (Mild), [Lettuce, Black Beans, R...     $8.69
# 1272  [Tomatillo Red Chili (Hot), [Lettuce, Rice, So...     $8.69
# 3156                      [[Black Beans, Rice, Cheese]]     $8.69
# 3195  [Fresh Tomato (Mild), [Lettuce, Black Beans, R...     $8.69
# 3196  [Fresh Tomato (Mild), [Lettuce, Black Beans, R...     $8.69
# 3252             [Fresh Tomato (Mild), [Lettuce, Rice]]     $8.69
# 3501                  [[Lettuce, Fajita Veggies, Rice]]     $8.69
# 3502                        [[Lettuce, Fajita Veggies]]     $8.69
# 3529             [Fresh Tomato (Mild), [Lettuce, Rice]]     $8.69
# 3530  [Fresh Tomato (Mild), [Lettuce, Pinto Beans, R...     $8.69
# 3532                  [[Lettuce, Fajita Veggies, Rice]]     $8.69
# 3540                  [[Lettuce, Fajita Veggies, Rice]]     $8.69
# 3822     [Fresh Tomato (Mild), [Lettuce, Rice, Cheese]]     $8.69
# 3902  [Fresh Tomato (Mild), [Black Beans, Rice, Sour...     $8.69
# 3988  [Tomatillo Red Chili (Hot), [Lettuce, Black Be...     $8.69
# 4056                                   [[Rice, Cheese]]     $8.69
# 4068                  [[Lettuce, Fajita Veggies, Rice]]     $8.69
#
#      total price  total_price
# 728        $8.69       $8.69
# 729        $8.69       $8.69
# 926        $8.69       $8.69
# 1272       $8.69       $8.69
# 3156       $8.69       $8.69
# 3195       $8.69       $8.69
# 3196       $8.69       $8.69
# 3252       $8.69       $8.69
# 3501       $8.69       $8.69
# 3502       $8.69       $8.69
# 3529       $8.69       $8.69
# 3530       $8.69       $8.69
# 3532       $8.69       $8.69
# 3540       $8.69       $8.69
# 3822       $8.69       $8.69
# 3902       $8.69       $8.69
# 3988       $8.69       $8.69
# 4056       $8.69       $8.69
# 4068       $8.69       $8.69
#       order_id  quantity             item_name  \
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 19          10         1          Chicken Bowl
# 35          18         1    Chicken Soft Tacos
# 36          18         1    Chicken Soft Tacos
# ...        ...       ...                   ...
# 4599      1827         1          Chicken Bowl
# 4604      1828         1          Chicken Bowl
# 4615      1832         1    Chicken Soft Tacos
# 4620      1834         1    Chicken Salad Bowl
# 4621      1834         1    Chicken Salad Bowl
#
#                                      choice_description item_price  \
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...     $8.75
# 35                     [Roasted Chili Corn Salsa, Rice]     $8.75
# 36        [Roasted Chili Corn Salsa, [Cheese, Lettuce]]     $8.75
# ...                                                 ...        ...
# 4599      [Roasted Chili Corn Salsa, [Cheese, Lettuce]]     $8.75
# 4604  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...     $8.75
# 4615   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $8.75
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
#      total price  total_price
# 11         $8.75       $8.75
# 12         $8.75       $8.75
# 19         $8.75       $8.75
# 35         $8.75       $8.75
# 36         $8.75       $8.75
# ...           ...         ...
# 4599       $8.75       $8.75
# 4604       $8.75       $8.75
# 4615       $8.75       $8.75
# 4620       $8.75       $8.75
# 4621       $8.75       $8.75
#
# [730 rows x 7 columns]
#       order_id  quantity            item_name choice_description item_price  \
# 792        326         2  Chips and Guacamole                NaN     $8.90
# 880        363         2  Chips and Guacamole                NaN     $8.90
# 978        402         2  Chips and Guacamole                NaN     $8.90
# 1258       511         2  Chips and Guacamole                NaN     $8.90
# 1346       549         2  Chips and Guacamole                NaN     $8.90
# 1351       552         2  Chips and Guacamole                NaN     $8.90
# 1423       577         2  Chips and Guacamole                NaN     $8.90
# 1824       737         2  Chips and Guacamole                NaN     $8.90
# 1881       759         2  Chips and Guacamole                NaN     $8.90
# 1978       798         2  Chips and Guacamole                NaN     $8.90
# 2019       814         2  Chips and Guacamole                NaN     $8.90
# 2036       818         2  Chips and Guacamole                NaN     $8.90
# 2251       907         2  Chips and Guacamole                NaN     $8.90
# 2453       973         2  Chips and Guacamole                NaN     $8.90
# 2608      1035         2  Chips and Guacamole                NaN     $8.90
# 2859      1136         2  Chips and Guacamole                NaN     $8.90
# 3066      1221         2  Chips and Guacamole                NaN     $8.90
# 3158      1261         2  Chips and Guacamole                NaN     $8.90
# 3791      1517         2  Chips and Guacamole                NaN     $8.90
# 4332      1729         2  Chips and Guacamole                NaN     $8.90
#
#       total price    total_price
# 792   $8.90 $8.90   $8.90 $8.90
# 880   $8.90 $8.90   $8.90 $8.90
# 978   $8.90 $8.90   $8.90 $8.90
# 1258  $8.90 $8.90   $8.90 $8.90
# 1346  $8.90 $8.90   $8.90 $8.90
# 1351  $8.90 $8.90   $8.90 $8.90
# 1423  $8.90 $8.90   $8.90 $8.90
# 1824  $8.90 $8.90   $8.90 $8.90
# 1881  $8.90 $8.90   $8.90 $8.90
# 1978  $8.90 $8.90   $8.90 $8.90
# 2019  $8.90 $8.90   $8.90 $8.90
# 2036  $8.90 $8.90   $8.90 $8.90
# 2251  $8.90 $8.90   $8.90 $8.90
# 2453  $8.90 $8.90   $8.90 $8.90
# 2608  $8.90 $8.90   $8.90 $8.90
# 2859  $8.90 $8.90   $8.90 $8.90
# 3066  $8.90 $8.90   $8.90 $8.90
# 3158  $8.90 $8.90   $8.90 $8.90
# 3791  $8.90 $8.90   $8.90 $8.90
# 4332  $8.90 $8.90   $8.90 $8.90
#       order_id  quantity         item_name  \
# 21          11         1  Barbacoa Burrito
# 27          14         1  Carnitas Burrito
# 31          16         1     Steak Burrito
# 33          17         1     Carnitas Bowl
# 46          21         1     Steak Burrito
# ...        ...       ...               ...
# 4054      1623         1        Steak Bowl
# 4089      1638         1     Steak Burrito
# 4267      1702         1        Steak Bowl
# 4268      1702         1     Steak Burrito
# 4508      1793         1     Steak Burrito
#
#                                      choice_description item_price  \
# 21    [[Fresh Tomato Salsa (Mild), Tomatillo-Green C...     $8.99
# 27    [[Tomatillo-Green Chili Salsa (Medium), Roaste...     $8.99
# 31    [[Roasted Chili Corn Salsa (Medium), Fresh Tom...     $8.99
# 33    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99
# 46    [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...     $8.99
# ...                                                 ...        ...
# 4054  [Fresh Tomato Salsa (Mild), [Sour Cream, Lettu...     $8.99
# 4089  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     $8.99
# 4267            [Rice, Tomatillo-Red Chili Salsa (Hot)]     $8.99
# 4268            [Rice, Tomatillo-Red Chili Salsa (Hot)]     $8.99
# 4508                                       [Brown Rice]     $8.99
#
#      total price  total_price
# 21         $8.99       $8.99
# 27         $8.99       $8.99
# 31         $8.99       $8.99
# 33         $8.99       $8.99
# 46         $8.99       $8.99
# ...           ...         ...
# 4054       $8.99       $8.99
# 4089       $8.99       $8.99
# 4267       $8.99       $8.99
# 4268       $8.99       $8.99
# 4508       $8.99       $8.99
#
# [246 rows x 7 columns]
#       order_id  quantity            item_name  \
# 8            4         1     Steak Soft Tacos
# 9            5         1        Steak Burrito
# 56          26         1  Barbacoa Soft Tacos
# 61          28         1     Steak Soft Tacos
# 81          36         1     Barbacoa Burrito
# ...        ...       ...                  ...
# 4562      1814         1        Carnitas Bowl
# 4578      1821         1     Carnitas Burrito
# 4602      1827         1     Barbacoa Burrito
# 4603      1827         1     Barbacoa Burrito
# 4612      1831         1        Carnitas Bowl
#
#                                      choice_description item_price  \
# 8     [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 56    [Fresh Tomato Salsa, [Fajita Vegetables, Black...     $9.25
# 61                         [Fresh Tomato Salsa, Cheese]     $9.25
# 81    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...     $9.25
# ...                                                 ...        ...
# 4562  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $9.25
# 4578  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...     $9.25
# 4602                      [Tomatillo Green Chili Salsa]     $9.25
# 4603                      [Tomatillo Green Chili Salsa]     $9.25
# 4612  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...     $9.25
#
#      total price  total_price
# 8          $9.25       $9.25
# 9          $9.25       $9.25
# 56         $9.25       $9.25
# 61         $9.25       $9.25
# 81         $9.25       $9.25
# ...           ...         ...
# 4562       $9.25       $9.25
# 4578       $9.25       $9.25
# 4602       $9.25       $9.25
# 4603       $9.25       $9.25
# 4612       $9.25       $9.25
#
# [398 rows x 7 columns]
#       order_id  quantity            item_name  \
# 607        250         1     Steak Salad Bowl
# 1418       576         1  Barbacoa Salad Bowl
# 1421       576         1  Barbacoa Salad Bowl
# 1825       738         1  Barbacoa Salad Bowl
# 1865       756         1  Carnitas Salad Bowl
# 2600      1032         1     Steak Salad Bowl
# 2624      1042         1     Steak Salad Bowl
# 3098      1235         1     Steak Salad Bowl
# 3115      1243         1  Carnitas Salad Bowl
# 3356      1346         1  Barbacoa Salad Bowl
# 4036      1615         1     Steak Salad Bowl
# 4241      1693         1     Steak Salad Bowl
# 4390      1751         1  Barbacoa Salad Bowl
# 4391      1752         1     Steak Salad Bowl
# 4419      1762         1     Steak Salad Bowl
# 4547      1807         1     Steak Salad Bowl
# 4572      1818         1     Steak Salad Bowl
#
#                                      choice_description item_price  \
# 607                       [Fresh Tomato Salsa, Lettuce]     $9.39
# 1418                         [Roasted Chili Corn Salsa]     $9.39
# 1421                         [Roasted Chili Corn Salsa]     $9.39
# 1825  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...     $9.39
# 1865   [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]     $9.39
# 2600  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $9.39
# 2624  [Fresh Tomato Salsa, [Black Beans, Sour Cream,...     $9.39
# 3098  [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $9.39
# 3115  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...     $9.39
# 3356  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...     $9.39
# 4036  [Fresh Tomato Salsa, [Fajita Vegetables, Chees...     $9.39
# 4241  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $9.39
# 4390  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...     $9.39
# 4391  [Fresh Tomato Salsa, [Black Beans, Pinto Beans...     $9.39
# 4419  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $9.39
# 4547  [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $9.39
# 4572  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $9.39
#
#      total price  total_price
# 607        $9.39       $9.39
# 1418       $9.39       $9.39
# 1421       $9.39       $9.39
# 1825       $9.39       $9.39
# 1865       $9.39       $9.39
# 2600       $9.39       $9.39
# 2624       $9.39       $9.39
# 3098       $9.39       $9.39
# 3115       $9.39       $9.39
# 3356       $9.39       $9.39
# 4036       $9.39       $9.39
# 4241       $9.39       $9.39
# 4390       $9.39       $9.39
# 4391       $9.39       $9.39
# 4419       $9.39       $9.39
# 4547       $9.39       $9.39
# 4572       $9.39       $9.39
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_18528\3631817380.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby("item_price").apply(print)
# Empty DataFrame
# Columns: []
# Index: []

# %%
c = df.groupby("item_name")["quantity"].sum()
c.sort_values(ascending = True )
print(c)
# Out:
# item_name
# 6 Pack Soft Drink                         55
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     12
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            211
# Bowl                                       4
# Burrito                                    6
# Canned Soda                              126
# Canned Soft Drink                        351
# Carnitas Bowl                             71
# Carnitas Burrito                          60
# Carnitas Crispy Tacos                      8
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chicken Crispy Tacos                      50
# Chicken Salad                              9
# Chicken Salad Bowl                       123
# Chicken Soft Tacos                       120
# Chips                                    230
# Chips and Fresh Tomato Salsa             130
# Chips and Guacamole                      506
# Chips and Mild Fresh Tomato Salsa          1
# Chips and Roasted Chili Corn Salsa        23
# Chips and Roasted Chili-Corn Salsa        18
# Chips and Tomatillo Green Chili Salsa     45
# Chips and Tomatillo Red Chili Salsa       50
# Chips and Tomatillo-Green Chili Salsa     33
# Chips and Tomatillo-Red Chili Salsa       25
# Crispy Tacos                               2
# Izze                                      20
# Nantucket Nectar                          29
# Salad                                      2
# Side of Chips                            110
# Steak Bowl                               221
# Steak Burrito                            386
# Steak Crispy Tacos                        36
# Steak Salad                                4
# Steak Salad Bowl                          31
# Steak Soft Tacos                          56
# Veggie Bowl                               87
# Veggie Burrito                            97
# Veggie Crispy Tacos                        1
# Veggie Salad                               6
# Veggie Salad Bowl                         18
# Veggie Soft Tacos                          8
# Name: quantity, dtype: int64
